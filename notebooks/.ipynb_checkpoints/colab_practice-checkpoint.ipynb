# %% [markdown]
# # Step 1 - Setup Google Colab
# ## Execute the following code exactly once  - and no more after

# %%
#@title Setup Google Colab by running this cell only once (ignore this if run locally) {display-mode: "form"}
import sys

if 'google.colab' in sys.modules:
    # Clone GitHub repository
    # !git clone https://github.com/epfl-exts/EPFL_EMBA.git
        
    # Copy files required to run the code
    # !cp -r "EPFL_EMBA/notebooks/data" "EPFL_EMBA/notebooks/data_prep_tools.py" "EPFL_EMBA/notebooks/EDA_tools.py" "EPFL_EMBA/notebooks/modeling_tools.py" . 
    
    # Install packages via pip
    # !pip install -r "EPFL_EMBA/colab-requirements.txt"
    
    # Restart Runtime
    import os
    os.kill(os.getpid(), 9)

# %% [markdown]
# # Start reading here
#
# Above you see the text  **> Google Colab Setup**.
# Below is a Play-button (triangle) to execute this code cell. If you see a Warning, press **Run anyway**.
#
# This will start setting up your environment which contains all the necessary libraries for this project.
# Don't be alarmed if the cell takes a while to execute. If it prints some information, that is a good sign. Just wait for it to finish.
#
# **Now:**
# Press the play button on the cell below and read the output.

# %%
print("Setup completed just fine.")
print("Please continue below")

# %% [markdown]
# # Step 2 - Let's orientate ourselves
#
# ## The menu bars
#
# ### Left menu bar

# %% [markdown]
# ![left_menu_bar.png](attachment:2276a0be-ec7d-4f87-9011-e4a2858c938e.png)

# %% [markdown]
# If you want to close the menubar, just click on the active (orange) option.

# %% [markdown]
# ### Top menu bar

# %% [markdown]
# ![top_menu_bar.png](attachment:1351e5ab-d91a-458b-a675-bab99575b307.png)

# %% [markdown]
# # Step 3 Let's run some code
#
# You can identify code cells be the square brackets in front of them.
# If the bracket is empty, i.e. [  ], the cell has not been executed.
# If you hover over it the Play-button appears and you can run the cell. Do that below

# %%
print("This cell has been executed if this text appears below it")

# %% [markdown]
# The number in front shows you the step within the overall execution.
#
# **Task:**
# * Execute the cell below
# * Change the text inside print()
# * Execute again to see the changes in particular the original output is lost. The numbering also changed.

# %%
print("Some changes yet")

# %% [markdown]
# # Step 4 - Restarting a session

# %% [markdown]
# To restart a session open the "Run all"-submenu and select the option.
# You can also use the menu under the "Runtime"-Tab at the top.
#
# !! Note the executed code won't disappear but the information stored in memory has been lost. You need to start from scratch.
#
# To empty all previous outputs use "Clear all outputs" from the "Run all"-submenu.
# You can also use the menu under the "Edit"-Tab.
#
# **Important** When you restart the session you do **not need to rerun the Google Colab Setup**. We only do the once!

# %% [markdown]
# # Step 5 - Order of execution matters
#
# Let's see an example.
# Keep an eye on the counter of the execution in front of the cell.
#
# 1. Run cells 1-3 below.
# 2. Run cell 3 two more times.
# 3. Run cell 2  and then cell 3.
# 4. Restart the kernel and run cell 3.
# 5. Restart the kernel again and run cells 1-3 again
# </div>

# %%
# Cell 1
name = "Peter PAN"
end = "!"

# %%
# Cell 2
greeting = name
print(greeting)

# %%
# Cell 3
name = "Wendy"
greeting = greeting + 2 * end
print(greeting)

# %% [markdown]
# ### Why does it matter?
#
# You can re-execute cells, for example to run the smae analysis with a different parameter. But sometimes that can lead to errors because other parts have not been updated simultaneously. This leads to error messages.
# BUT DON'T PANIC!
# Just calmly execute the necessary cells in the right order.

# %% [markdown]
# ## THE END
#
# We let you explore the rest by yourself.
#
# **Next steps**
#
# * We will do the warmup task
